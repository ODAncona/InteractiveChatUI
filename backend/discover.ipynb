# %%
import joblib

# Load the .joblib file
result = joblib.load('result.joblib')

# Explore the contents
print(type(result))  # Check the type of the loaded object
print(result)        # Print the content or structure of the object
# Out:
# <class 'exa_py.api.SearchResponse'>
# Title: EU gives green light to revamp of Europe's main climate policy
# URL: https://www.reuters.com/world/europe/eu-countries-approve-reform-blocs-carbon-market-2023-04-25/
# ID: https://www.reuters.com/world/europe/eu-countries-approve-reform-blocs-carbon-market-2023-04-25/
# Score: 0.2936986982822418
# Published Date: 2023-04-25T00:00:00.000Z
# Author: Kate Abnett
# Image: https://www.reuters.com/resizer/v2/https%3A%2F%2Fcloudfront-us-east-2.images.arcpublishing.com%2Freuters%2FMJUD4TSUR5JTDKS2KRIZFYR564.jpg?auth=76d0e1bd7006e081fe3c7e6fb3cae097fe44ed836b31b07bf8cf216b47dff5a8&height=1005&width=1920&quality=80&smart=true
# Favicon: https://www.reuters.com/pf/resources/images/reuters/favicon/tr_fvcn_kinesis_32x32_v2.ico?d=280
# Extras: None
# Subpages: None
# Text: [Skip to main content](https://www.reuters.com/world/europe/eu-countries-approve-reform-blocs-carbon-market-2023-04-25/#main-content)
#
# ...
